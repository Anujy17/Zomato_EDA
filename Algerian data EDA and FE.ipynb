# %% [markdown]
# # EDA and FE on algerian forest fire dataset

# %% [markdown]
# link for the dataset - https://www.kaggle.com/datasets/nitinchoudhary012/algerian-forest-fires-dataset

# %% [markdown]
# <b>importing required packages</b>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#reading the dataset
df=pd.read_csv('Algerian_forest_fires_dataset.csv')

# %%
#understanding the dataset
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0   1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1   2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2   3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3   4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4   5     6  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
df.tail()
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 242  26     9  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 243  27     9  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 244  28     9  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 245  29     9  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 246  30     9  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes
# 242  6.5       fire
# 243    0   not fire
# 244  0.2   not fire
# 245  0.7   not fire
# 246  0.5  not fire

# %%
#getting the shape of dataset
df.shape
# Out:
# (247, 14)

# %%
#getting info about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
# dtypes: object(14)
# memory usage: 27.1+ KB

# %%
df.describe()
# Out:
#         day month  year Temperature   RH   Ws Rain   FFMC  DMC   DC  ISI  BUI  \
# count   246   245   245         245  245  245   245   245  245  245  245  245
# unique   33     5     2          20   63   19    40   174  167  199  107  175
# top       1     7  2012          35   64   14     0  88.9  7.9    8  1.1    3
# freq      8    62   244          29   10   43   133     8    5    5    8    5
#
#         FWI Classes
# count   245       244
# unique  127         9
# top     0.4   fire
# freq     12       131

# %%
#getting the columns list

df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  '],
#       dtype='object')

# %%
#removing extra space around the column names
df.columns=df.columns.str.strip()

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes'],
#       dtype='object')

# %%
#checking for the null values
df.isnull().sum()
# Out:
# day            1
# month          2
# year           2
# Temperature    2
# RH             2
# Ws             2
# Rain           2
# FFMC           2
# DMC            2
# DC             2
# ISI            2
# BUI            2
# FWI            2
# Classes        3
# dtype: int64

# %%
# Categorizing the dataset into two halves for two regions for better visulization
df.loc[:122,'Region']=1
df.loc[122:,'Region']=2
df[['Region']] = df[['Region']].astype(int)

# %%
#checking for null rows
df[df.isnull().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain  \
# 122                            NaN   NaN   NaN         NaN  NaN  NaN  NaN
# 123  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN  NaN
# 168                             14     7  2012          37   37   18  0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes  Region
# 122   NaN   NaN     NaN   NaN   NaN      NaN     NaN       2
# 123   NaN   NaN     NaN   NaN   NaN      NaN     NaN       2
# 168  88.9  12.9  14.6 9  12.5  10.4  fire        NaN       2

# %%
#dropping the null values of 122 and 123 row
df.drop([122,123],inplace=True)

# %%
df.reset_index(inplace=True)
df.drop('index',axis=1,inplace=True)

# %%
df.loc[:122,"Region"]='bejaia'
df.loc[122:,"Region"]='Sidi-Bel Abbes'

# %%
#dropping the nan values from the dataset
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
# RH             0
# Ws             0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# Region         0
# dtype: int64

# %% [markdown]
#  <b>nan values has been removed

# %%
df['Classes'].unique()
# Out:
# array(['not fire   ', 'fire   ', 'fire', 'fire ', 'not fire', 'not fire ',
#        'Classes  ', 'not fire     ', 'not fire    '], dtype=object)

# %% [markdown]
# <b> it contains duplicates with the spaces

# %%
df['Classes']=df['Classes'].str.strip()

# %%
df.Classes.unique()
# Out:
# array(['not fire', 'fire', 'Classes'], dtype=object)

# %%
df.dtypes
# Out:
# day            object
# month          object
# year           object
# Temperature    object
# RH             object
# Ws             object
# Rain           object
# FFMC           object
# DMC            object
# DC             object
# ISI            object
# BUI            object
# FWI            object
# Classes        object
# Region         object
# dtype: object

# %%
#checking for the duplicate rows
df[df['Classes']=='Classes']
# Out:
#      day  month  year  Temperature   RH   Ws   Rain  FFMC  DMC  DC  ISI  BUI  \
# 122  day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI
#
#      FWI  Classes          Region
# 122  FWI  Classes  Sidi-Bel Abbes

# %%
#dropping the duplicate row ie row number 122
df.drop(122,inplace=True)

# %%
df.Classes.unique()
df.reset_index(inplace=True)
df.drop('index',axis=1,inplace=True)

# %%
df.dtypes
# Out:
# day            object
# month          object
# year           object
# Temperature    object
# RH             object
# Ws             object
# Rain           object
# FFMC           object
# DMC            object
# DC             object
# ISI            object
# BUI            object
# FWI            object
# Classes        object
# Region         object
# dtype: object

# %%
#converting the columns to required datatypes to int
df[['day', 'month', 'year', 'Temperature', 'RH', 'Ws']]=df[['day', 'month', 'year', 'Temperature', 'RH', 'Ws']].astype(int)

# %%
df.dtypes
# Out:
# day             int32
# month           int32
# year            int32
# Temperature     int32
# RH              int32
# Ws              int32
# Rain           object
# FFMC           object
# DMC            object
# DC             object
# ISI            object
# BUI            object
# FWI            object
# Classes        object
# Region         object
# dtype: object

# %%
df[['Rain', 'FFMC','DMC', 'DC', 'ISI', 'BUI', 'FWI']]=df[['Rain', 'FFMC','DMC', 'DC', 'ISI', 'BUI', 'FWI']].astype('float')

# %%
df.dtypes
# Out:
# day              int32
# month            int32
# year             int32
# Temperature      int32
# RH               int32
# Ws               int32
# Rain           float64
# FFMC           float64
# DMC            float64
# DC             float64
# ISI            float64
# BUI            float64
# FWI            float64
# Classes         object
# Region          object
# dtype: object

# %%
# we can drop year column as it has same year
df.drop('year',axis=1,inplace=True)

# %%
#classifying the data based on fire or not
df['Classes'] = np.where(df['Classes']=='not fire',0,1)

# %%
df.describe(include='all')
# Out:
#                day       month  Temperature          RH          Ws  \
# count   243.000000  243.000000   243.000000  243.000000  243.000000
# unique         NaN         NaN          NaN         NaN         NaN
# top            NaN         NaN          NaN         NaN         NaN
# freq           NaN         NaN          NaN         NaN         NaN
# mean     15.761317    7.502058    32.152263   62.041152   15.493827
# std       8.842552    1.114793     3.628039   14.828160    2.811385
# min       1.000000    6.000000    22.000000   21.000000    6.000000
# 25%       8.000000    7.000000    30.000000   52.500000   14.000000
# 50%      16.000000    8.000000    32.000000   63.000000   15.000000
# 75%      23.000000    8.000000    35.000000   73.500000   17.000000
# max      31.000000    9.000000    42.000000   90.000000   29.000000
#
#               Rain        FFMC         DMC          DC         ISI  \
# count   243.000000  243.000000  243.000000  243.000000  243.000000
# ...

# %%
# finding the correlation
df.corr()
# Out:
#                   day     month  Temperature        RH        Ws      Rain  \
# day          1.000000 -0.000369     0.097227 -0.076034  0.047812 -0.112523
# month       -0.000369  1.000000    -0.056781 -0.041252 -0.039880  0.034822
# Temperature  0.097227 -0.056781     1.000000 -0.651400 -0.284510 -0.326492
# RH          -0.076034 -0.041252    -0.651400  1.000000  0.244048  0.222356
# Ws           0.047812 -0.039880    -0.284510  0.244048  1.000000  0.171506
# Rain        -0.112523  0.034822    -0.326492  0.222356  0.171506  1.000000
# FFMC         0.224956  0.017030     0.676568 -0.644873 -0.166548 -0.543906
# DMC          0.491514  0.067943     0.485687 -0.408519 -0.000721 -0.288773
# DC           0.527952  0.126511     0.376284 -0.226941  0.079135 -0.298023
# ISI          0.180543  0.065608     0.603871 -0.686667  0.008532 -0.347484
# BUI          0.517117  0.085073     0.459789 -0.353841  0.031438 -0.299852
# ...

# %%
#correlation using the heatmap
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <b>+ve correlated values are BUI and DMC ie 0.98

# %%
numeric_features=[fea for fea in df.columns if df[fea].dtypes!='O']

# %%
sns.pairplot(df)

# %%
plt.figure(figsize=(15,10))
plt.suptitle('Analysis of numerical features')
for i in range(0,len(numeric_features)):
    plt.subplot(5,3,i+1)
    sns.kdeplot(x=df[numeric_features[i]],shade=True,color='blue')
    plt.xlabel(numeric_features[i])
    plt.tight_layout()

# %%
df.hist(figsize=(15,10))
# Out:
# array([[<AxesSubplot:title={'center':'day'}>,
#         <AxesSubplot:title={'center':'month'}>,
#         <AxesSubplot:title={'center':'Temperature'}>,
#         <AxesSubplot:title={'center':'RH'}>],
#        [<AxesSubplot:title={'center':'Ws'}>,
#         <AxesSubplot:title={'center':'Rain'}>,
#         <AxesSubplot:title={'center':'FFMC'}>,
#         <AxesSubplot:title={'center':'DMC'}>],
#        [<AxesSubplot:title={'center':'DC'}>,
#         <AxesSubplot:title={'center':'ISI'}>,
#         <AxesSubplot:title={'center':'BUI'}>,
#         <AxesSubplot:title={'center':'FWI'}>],
#        [<AxesSubplot:title={'center':'Classes'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %% [markdown]
# <b> temperature is noramally distributed

# %%
percentage=df['Classes'].value_counts(normalize=True)*100
percentage
# Out:
# 1    56.378601
# 0    43.621399
# Name: Classes, dtype: float64

# %%
plt.figure(figsize=(15,10))
plt.pie(percentage,labels=['Fire','Not Fire'],autopct="%1.1f%%")
plt.title('Pie chart of classes')
plt.show()

# %% [markdown]
# <b>we can see there is more data about fire

# %%
plt.figure(figsize=(15,10))
sns.boxplot(data=df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <b>it represents Rain, FFMC, DMC, DC, BUI contain more outliers

# %%
plt.figure(figsize=(15,10))
sns.barplot(x='Region',y='Classes',data=df)
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Classes'>

# %% [markdown]
#  <b>
# we can see sidi-bel-abbes has more fire than bejaia</b>

# %%
sns.barplot(x='Region',y='Rain',data=df)
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Rain'>

# %% [markdown]
#  <b>bajaia has more rains due to which possibility of fire is less

# %%
sns.barplot(x='month',y='Classes',data=df)
# Out:
# <AxesSubplot:xlabel='month', ylabel='Classes'>

# %% [markdown]
# <b>in the month of august it has more fire

# %%
sns.barplot(x="Temperature",y="Rain",data=df)
# Out:
# <AxesSubplot:xlabel='Temperature', ylabel='Rain'>

# %% [markdown]
# <b> when temperature is 22 then there is more rain
